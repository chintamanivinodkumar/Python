# %%
import pandas as pd
data = pd.read_csv("Ubertrips.csv")
data
# Out:
#     TripID  TripLength  MaxSpeed  MostFreqSpeed  TripDuration  Brakes  \
# 0        1          21        51             14            93     307
# 1        2         148       130            106           156     226
# 2        3          18        38             16           100     351
# 3        4          22        43             48            36      17
# 4        5         183       108             90           171      88
# ..     ...         ...       ...            ...           ...     ...
# 86      87          21        42             13            92     360
# 87      88         183       126             89           149     189
# 88      89          22        44             12            72     349
# 89      90         163       135             91           129     202
# 90      91          20        64             42            27      36
#
#     IdlingTime  Honking
# 0           27      112
# 1            5      114
# 2           26      107
# 3            4        5
# ...

# %%
data.head()
# Out:
#    TripID  TripLength  MaxSpeed  MostFreqSpeed  TripDuration  Brakes  \
# 0       1          21        51             14            93     307
# 1       2         148       130            106           156     226
# 2       3          18        38             16           100     351
# 3       4          22        43             48            36      17
# 4       5         183       108             90           171      88
#
#    IdlingTime  Honking
# 0          27      112
# 1           5      114
# 2          26      107
# 3           4        5
# 4           5       29

# %%
data.tail()
# Out:
#     TripID  TripLength  MaxSpeed  MostFreqSpeed  TripDuration  Brakes  \
# 86      87          21        42             13            92     360
# 87      88         183       126             89           149     189
# 88      89          22        44             12            72     349
# 89      90         163       135             91           129     202
# 90      91          20        64             42            27      36
#
#     IdlingTime  Honking
# 86          24       98
# 87           5      130
# 88          24       93
# 89           5      144
# 90           5       20

# %%
data.describe()
# Out:
#          TripID  TripLength    MaxSpeed  MostFreqSpeed  TripDuration  \
# count  91.00000   91.000000   91.000000      91.000000     91.000000
# mean   46.00000   70.769231   70.362637      50.648352     87.373626
# std    26.41338   73.302126   34.509424      34.349632     47.123160
# min     1.00000   16.000000   35.000000      12.000000     22.000000
# 25%    23.50000   20.000000   42.000000      15.500000     34.500000
# 50%    46.00000   21.000000   54.000000      42.000000     88.000000
# 75%    68.50000  163.000000  105.500000      89.000000    133.000000
# max    91.00000  210.000000  138.000000     118.000000    171.000000
#
#            Brakes  IdlingTime     Honking
# count   91.000000   91.000000   91.000000
# mean   135.439560   11.593407   49.923077
# std    114.758607    9.796800   46.371023
# min     14.000000    4.000000    4.000000
# 25%     36.500000    5.000000   20.000000
# 50%    100.000000    5.000000   25.000000
# 75%    198.000000   24.000000   97.500000
# ...

# %%
data
# Out:
#     TripID  TripLength  MaxSpeed  MostFreqSpeed  TripDuration  Brakes  \
# 0        1          21        51             14            93     307
# 1        2         148       130            106           156     226
# 2        3          18        38             16           100     351
# 3        4          22        43             48            36      17
# 4        5         183       108             90           171      88
# ..     ...         ...       ...            ...           ...     ...
# 86      87          21        42             13            92     360
# 87      88         183       126             89           149     189
# 88      89          22        44             12            72     349
# 89      90         163       135             91           129     202
# 90      91          20        64             42            27      36
#
#     IdlingTime  Honking
# 0           27      112
# 1            5      114
# 2           26      107
# 3            4        5
# ...

# %%
#PLotting the data

import matplotlib.pyplot as plt
x = data["TripLength"]
y = data["MaxSpeed"]
plt.plot(x,y,color = "Blue")
plt.xlabel("TripLength")
plt.ylabel("MaxSpeed")
plt.title("Line plot")
plt.show()

# %%
#Bar Graph

import matplotlib.pyplot as plt
x = data["TripLength"]
y = data["MaxSpeed"]
plt.bar(x,y,color = "Red")
plt.xlabel("TripLength")
plt.ylabel("MaxSpeed")
plt.title("Line plot")
plt.show()

# %%
#scatter

import matplotlib.pyplot as plt
x = data["Honking"]
y = data["TripDuration"]
plt.scatter(x,y,color = "Black")
plt.xlabel("Honking")
plt.ylabel("TripDuration")
plt.title("Line plot")
plt.show()

# %%
data
# Out:
#     TripID  TripLength  MaxSpeed  MostFreqSpeed  TripDuration  Brakes  \
# 0        1          21        51             14            93     307
# 1        2         148       130            106           156     226
# 2        3          18        38             16           100     351
# 3        4          22        43             48            36      17
# 4        5         183       108             90           171      88
# ..     ...         ...       ...            ...           ...     ...
# 86      87          21        42             13            92     360
# 87      88         183       126             89           149     189
# 88      89          22        44             12            72     349
# 89      90         163       135             91           129     202
# 90      91          20        64             42            27      36
#
#     IdlingTime  Honking
# 0           27      112
# 1            5      114
# 2           26      107
# 3            4        5
# ...

# %%
#pie chart

import matplotlib.pyplot as plt
x = data["Honking"]
plt.pie(x,shadow = True)
plt.ylabel("Honking")
plt.title("Pie plot")
plt.show()

# %%
#Histogram plot

import matplotlib.pyplot as plt
x = data["Honking"]
y = data["Brakes"]
plt.hist(y,color = "Green")
plt.xlabel("Honking")
plt.ylabel("Brakes")
plt.title("Histogram")
plt.show()

# %%
#Box plot

import matplotlib.pyplot as plt
items = [data.TripLength,data.TripDuration,data.MostFreqSpeed,data.Brakes]
plt.boxplot(items)
plt.title("Box Plot")
plt.show()
