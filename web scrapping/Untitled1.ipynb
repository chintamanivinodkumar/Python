# %%
from bs4 import BeautifulSoup
import requests
import csv
url = 'https://stats.espncricinfo.com/ci/engine/stats/index.html?class=1;result=1;template=results;type=batting'
p = requests.get(url)
soup = BeautifulSoup(p.content, 'html.parser')
 
content = soup.find_all('tr', class_ = 'pn1650M')
Headrow =['player','span', 'mat','inns', 'battingDecesending','Hs', 'Bf','Sr','Ave',]
itemsfull=[]
 
for item in content:
  items =[]
  playerdata = item.find_all('td')
  for i in playerdata:
    items.append(i.text)
  itemsfull.append(items)
 
  
with open('Testbatting.csv','w') as csvfile:
  csvwriter = csv.writer(csvfile)
  csvwriter.writerow(Headrow)
  csvwriter.writerows(itemsfull)
 
 
  
import pandas as pd
data=pd.read_csv('Testbatting.csv')
data
# Out:
# Empty DataFrame
# Columns: [player, span, mat, inns, battingDecesending, Hs, Bf, Sr, Ave]
# Index: []

# %%
# Scrap data from Flipkart for Redmi Mobile Phones

from bs4 import BeautifulSoup
import requests
import csv
import pandas as pd

url = "https://www.flipkart.com/search?q=redmi&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"
p = requests.get(url)
soup = BeautifulSoup(p.content,'html.parser')
print(p)
content = soup.find_all('div', class_="_2kHMtA")
fheader = ["Product Name","Price","Original Price","Discount"]

itemfull = []

for item in content:
  items = []
  productname = item.find('div', class_="_4rR01T")
  price = item.find('div', class_="_30jeq3 _1_WHN1")
  original = item.find('div', class_="_3I9_wc _27UcVY")
  discount = item.find('div', class_="_3Ay6Sb")
  items.append(productname.text)
  if(price is not None):
    items.append(price.text)
  else:
    items.append("Price is NA")
  if(original is not None):
    items.append(original.text)
  else:
    items.append("No Original Price")
  if(discount is not None):
    items.append(discount.text)
  else:
    items.append("No Discount")
  itemfull.append(items)

pd.DataFrame(itemfull).to_csv("flipred.csv",header=fheader)
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup
import requests
import csv
import pandas as pd


url = "https://www.flipkart.com/search?q=shoes&as=on&as-show=on&otracker=AS_Query_TrendingAutoSuggest_2_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_2_0_na_na_na&as-pos=2&as-type=TRENDING&suggestionId=shoes&requestId=a025b3cd-a9b4-4028-86c5-eddedf01f2e7"
p = requests.get(url)
soup = BeautifulSoup(p.content,'html.parser')
print(p)
# Out:
# <Response [200]>

# %%
content = soup.find_all('div', class_="_13oc-S")

# %%
fheader = ["Product Name","Price","Original Price","Discount"]

# %%
itemfull = []

# %%
for item in content:
  items = []
  productname = item.find('div', class_="_2WkVRV")
  price = item.find('div', class_="_30jeq3")
  original_price = item.find('div', class_="_3I9_wc")
  discount = item.find('div', class_="_3Ay6Sb")
  items.append(productname.text)
  if(price is not None):
    items.append(price.text)
  else:
    items.append("Price is NA")
  if(original_price is not None):
    items.append(original_price.text)
  else:
    items.append("No Original Price")
  if(discount is not None):
    items.append(discount.text)
  else:
    items.append("No Discount")
  itemfull.append(items)



data=pd.read_csv('Puma.csv')
data
# Out:
#     Unnamed: 0         Product Name Price Original Price Discount
# 0            0                  SFR  ₹599           ₹998  39% off
# 1            1                 aadi  ₹499         ₹1,999  75% off
# 2            2  World Wear Footwear  ₹299           ₹998  70% off
# 3            3                 aadi  ₹399           ₹999  60% off
# 4            4             RapidBox  ₹600           ₹999  39% off
# 5            5                  SFR  ₹599           ₹887  32% off
# 6            6                asian  ₹526           ₹999  47% off
# 7            7                 aadi  ₹499           ₹999  50% off
# 8            8                 aadi  ₹699         ₹1,999  65% off
# 9            9                  SFR  ₹599           ₹954  37% off
# 10          10                  SFR  ₹599           ₹998  39% off
# 11          11                 aadi  ₹499         ₹1,999  75% off
# 12          12  World Wear Footwear  ₹299           ₹998  70% off
# 13          13                 aadi  ₹399           ₹999  60% off
# 14          14             RapidBox  ₹600           ₹999  39% off
# 15          15                  SFR  ₹599           ₹887  32% off
# 16          16                asian  ₹526           ₹999  47% off
# 17          17                 aadi  ₹499           ₹999  50% off
# 18          18                 aadi  ₹699         ₹1,999  65% off
# 19          19                  SFR  ₹599           ₹954  37% off
# 20          20                  SFR  ₹599           ₹998  39% off
# 21          21                 aadi  ₹499         ₹1,999  75% off
# 22          22  World Wear Footwear  ₹299           ₹998  70% off
# 23          23                 aadi  ₹399           ₹999  60% off
# 24          24             RapidBox  ₹600           ₹999  39% off
# 25          25                  SFR  ₹599           ₹887  32% off
# 26          26                asian  ₹526           ₹999  47% off
# 27          27                 aadi  ₹499           ₹999  50% off
# 28          28                 aadi  ₹699         ₹1,999  65% off
# 29          29                  SFR  ₹599           ₹954  37% off
