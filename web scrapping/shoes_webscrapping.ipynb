# %%
from bs4 import BeautifulSoup
import requests
import csv
import pandas as pd


url = "https://www.flipkart.com/search?q=shoes&as=on&as-show=on&otracker=AS_Query_TrendingAutoSuggest_2_0_na_na_na&otracker1=AS_Query_TrendingAutoSuggest_2_0_na_na_na&as-pos=2&as-type=TRENDING&suggestionId=shoes&requestId=a025b3cd-a9b4-4028-86c5-eddedf01f2e7"
p = requests.get(url)
soup = BeautifulSoup(p.content,'html.parser')
print(p)
# Out:
# <Response [200]>

# %%
content = soup.find_all('div', class_="_13oc-S")

# %%
fheader = ["Product Name","Price","Original Price","Discount"]

# %%
itemfull = []

# %%
for item in content:
  items = []
  productname = item.find('div', class_="_2WkVRV")
  price = item.find('div', class_="_30jeq3")
  original_price = item.find('div', class_="_3I9_wc")
  discount = item.find('div', class_="_3Ay6Sb")
  items.append(productname.text)
  if(price is not None):
    items.append(price.text)
  else:
    items.append("Price is NA")
  if(original_price is not None):
    items.append(original_price.text)
  else:
    items.append("No Original Price")
  if(discount is not None):
    items.append(discount.text)
  else:
    items.append("No Discount")
  itemfull.append(items)

pd.DataFrame(itemfull).to_csv("Shoes.csv",header=fheader)
data=pd.read_csv('Shoes.csv')
data
# Out:
#     Unnamed: 0         Product Name Price Original Price Discount
# 0            0                CLYMB  ₹288           ₹999  71% off
# 1            1             HOTSTYLE  ₹376           ₹999  62% off
# 2            2  World Wear Footwear  ₹419           ₹998  58% off
# 3            3                 aadi  ₹499         ₹1,999  75% off
# 4            4                asian  ₹526           ₹999  47% off
# 5            5       Mast & Harbour  ₹399           ₹999  60% off
# 6            6                asian  ₹799         ₹1,299  38% off
# 7            7  World Wear Footwear  ₹419           ₹999  58% off
# 8            8               CAMPUS  ₹899         ₹1,049  14% off
# 9            9              JK PORT  ₹512         ₹1,149  55% off
# 10          10                CLYMB  ₹288           ₹999  71% off
# 11          11             HOTSTYLE  ₹376           ₹999  62% off
# 12          12  World Wear Footwear  ₹419           ₹998  58% off
# 13          13                 aadi  ₹499         ₹1,999  75% off
# 14          14                asian  ₹526           ₹999  47% off
# 15          15       Mast & Harbour  ₹399           ₹999  60% off
# 16          16                asian  ₹799         ₹1,299  38% off
# 17          17  World Wear Footwear  ₹419           ₹999  58% off
# 18          18               CAMPUS  ₹899         ₹1,049  14% off
# 19          19              JK PORT  ₹512         ₹1,149  55% off
