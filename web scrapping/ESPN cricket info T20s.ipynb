# %%
from bs4 import BeautifulSoup
import requests
import csv
url = 'https://stats.espncricinfo.com/ci/engine/stats/index.html?class=3;result=1;template=results;type=batting'
p = requests.get(url)
soup = BeautifulSoup(p.content, 'html.parser')
 
content = soup.find_all('tr', class_ = 'data1')
Headrow =['player','span', 'mat','inns', 'battingDecesending','Hs', 'Bf','Sr','Ave',]
itemsfull=[]
 
for item in content:
  items =[]
  playerdata = item.find_all('td')
  for i in playerdata:
    items.append(i.text)
  itemsfull.append(items)
 
  
with open('T20Isbatting.csv','w') as csvfile:
  csvwriter = csv.writer(csvfile)
  csvwriter.writerow(Headrow)
  csvwriter.writerows(itemsfull)
 
 
  
import pandas as pd
data=pd.read_csv('T20Isbatting.csv')
data
# Out:
#                                                       player  span     mat  \
# RG Sharma (IND)         2007-2022 99 94 14 3039 118    37.98  2131  142.60
# V Kohli (IND)           2010-2022 73 69 28 2799 122*   68.26  2012  139.11
# Babar Azam (PAK)        2016-2022 64 63 11 2353 122    45.25  1796  131.01
# MJ Guptill (NZ)         2009-2022 68 65 7  2222 101*   38.31  1555  142.89
# Mohammad Rizwan (PAK)   2015-2022 47 42 13 2009 104*   69.27  1510  133.04
# DA Warner (AUS)         2009-2022 58 58 8  1944 100*   38.88  1265  153.67
# AJ Finch (AUS)          2011-2022 54 54 10 1901 172    43.20  1273  149.33
# KL Rahul (IND)          2016-2022 48 47 7  1814 101*   45.35  1297  139.86
# Mohammad Hafeez (PAK)   2006-2021 70 64 9  1799 86*    32.70  1421  126.60
# Shoaib Malik (PAK)      2006-2021 86 76 30 1768 63*    38.43  1353  130.67
# Mohammad Shahzad (AFG)  2010-2021 48 48 3  1708 118*   37.95  1242  137.52
# ...

# %%
from bs4 import BeautifulSoup
import requests
import csv
url = 'https://stats.espncricinfo.com/ci/engine/stats/index.html?class=3;result=1;template=results;type=batting'
p = requests.get(url)
soup = BeautifulSoup(p.content, 'html.parser')
 
content = soup.find_all('tr', class_ = 'data1')
Headrow =['player','span', 'mat','inns', 'battingDecesending','Hs', 'Bf','Sr','Ave',]
itemsfull=[]
 
for item in content:
  items =[]
  playerdata = item.find_all('td')
  for i in playerdata:
    items.append(i.text)
  itemsfull.append(items)
 
  
with open('T20Is.csv','w') as csvfile:
  csvwriter = csv.writer(csvfile)
  csvwriter.writerow(Headrow)
  csvwriter.writerows(itemsfull)
 
 
  
import pandas as pd
data=pd.read_csv('T20Isbatting.csv')
data
# Out:
#                 player       span   mat  inns  battingDecesending      Hs  \
# 0                  NaN        NaN   NaN   NaN                 NaN     NaN
# 1    RG Sharma (INDIA)  2007-2022  89.0  84.0                13.0  2826.0
# 2                  NaN        NaN   NaN   NaN                 NaN     NaN
# 3      V Kohli (INDIA)  2010-2022  62.0  58.0                22.0  2223.0
# 4                  NaN        NaN   NaN   NaN                 NaN     NaN
# ..                 ...        ...   ...   ...                 ...     ...
# 95   KJ Coetzer (SCOT)  2008-2021  31.0  31.0                 2.0   856.0
# 96                 NaN        NaN   NaN   NaN                 NaN     NaN
# 97  KC Sangakkara (SL)  2006-2014  34.0  32.0                 7.0   855.0
# 98                 NaN        NaN   NaN   NaN                 NaN     NaN
# 99    LRPL Taylor (NZ)  2006-2020  49.0  42.0                14.0   828.0
#
#      Bf     Sr     Ave  Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# ...
